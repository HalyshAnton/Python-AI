# %% [markdown]
# <a href="https://colab.research.google.com/github/HalyshAnton/Python-AI/blob/AI_3_practice/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0_%D0%BB%D1%96%D0%BD%D1%96%D0%B9%D0%BD%D0%B0_%D1%80%D0%B5%D0%B3%D1%80%D0%B5%D1%81%D1%96%D1%8F2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/HalyshAnton/IT-Step-Pyton-AI/main/module3/data/Used%20Car%20Dataset.csv", index_col="Unnamed: 0")
df.drop(columns=['car_name', 'registration_year', 'ownsership', 'transmission'], inplace=True)

# %% [markdown]
# Дані про ціни вживаних автомобілів у Індії
# * car_name - назва авто у форматі 'рік компанія основна назва'
# * registration_year - місяць та рік реєстрації
# * ownsership - кількість власників у форматі 'Second owner'
# * transmission - тип коробки передач
# * insurance_validity - тип страховки
# * fuel_type - вид палива
# * seats - кількість сидінь
# * kms_driven - пробіг
# * manufacturing_year - рік виробництва, має тип object, потрібно застосувати astype(int)
# * mileage(kmpl) - скільки кілометрів проїде за літр палива
# * engine(cc) - об'єм двигуна у мл
# * max_power(bhp) - потужність у кінських силах
# * torque(Nm) - крутний момент двигуна
# * price(in lakhs) - ціна у сто тисяч рупій
#
# [Повний аналіз даних](https://www.kaggle.com/code/abdelrasoul/used-cars-prices-prediction)

# %%
df.head()
# Out:
#   insurance_validity fuel_type  seats  kms_driven manufacturing_year  \
# 0      Comprehensive    Petrol      5       56000               2017
# 1      Comprehensive    Petrol      5       30615               2020
# 2      Comprehensive    Diesel      5       24000               2018
# 3      Comprehensive    Petrol      5       18378               2019
# 4      Comprehensive    Petrol      5       44900               2019
#
#    mileage(kmpl)  engine(cc)  max_power(bhp)  torque(Nm)  price(in lakhs)
# 0           7.81      2996.0          2996.0       333.0            63.75
# 1          17.40       999.0           999.0      9863.0             8.99
# 2          20.68      1995.0          1995.0       188.0            23.75
# 3          16.50      1353.0          1353.0     13808.0            13.56
# 4          14.67      1798.0          1798.0     17746.0            24.00

# %%
#df = df[['fuel_type', 'kms_driven', 'engine(cc)', 'price(in lakhs)']]
df.head()
# Out:
#   insurance_validity fuel_type  seats  kms_driven manufacturing_year  \
# 0      Comprehensive    Petrol      5       56000               2017
# 1      Comprehensive    Petrol      5       30615               2020
# 2      Comprehensive    Diesel      5       24000               2018
# 3      Comprehensive    Petrol      5       18378               2019
# 4      Comprehensive    Petrol      5       44900               2019
#
#    mileage(kmpl)  engine(cc)  max_power(bhp)  torque(Nm)  price(in lakhs)
# 0           7.81      2996.0          2996.0       333.0            63.75
# 1          17.40       999.0           999.0      9863.0             8.99
# 2          20.68      1995.0          1995.0       188.0            23.75
# 3          16.50      1353.0          1353.0     13808.0            13.56
# 4          14.67      1798.0          1798.0     17746.0            24.00

# %%
df.shape
# Out:
# (1553, 10)

# %% [markdown]
# # Завдання 1
# Виведіть основні числові характеристики даних, розділіть на тренувальну та тестову чатини

# %%
df = df[df['price(in lakhs)'] < 40000]
df = df[df['engine(cc)'] < 0.5e6]
df = df[df['kms_driven'] < 700_000]

df.describe()
# Out:
#               seats     kms_driven  mileage(kmpl)    engine(cc)  \
# count   1534.000000    1534.000000    1534.000000   1534.000000
# mean      92.542373   51864.054759     218.606734   2293.719035
# std     2418.253136   29784.791033     548.066747   3736.986138
# min        4.000000     620.000000       7.810000      5.000000
# 25%        5.000000   30000.000000      16.225000   1197.000000
# 50%        5.000000   49000.000000      18.900000   1462.000000
# 75%        5.000000   70000.000000      21.790000   1995.000000
# max    67000.000000  260000.000000    3996.000000  38487.000000
#
#        max_power(bhp)    torque(Nm)  price(in lakhs)
# count     1534.000000  1.533000e+03      1534.000000
# mean      2293.719035  1.245902e+04        14.951982
# std       3736.986138  8.179026e+04        18.043409
# min          5.000000  5.000000e+00         1.000000
# 25%       1197.000000  4.000000e+02         4.732500
# 50%       1462.000000  1.173000e+03         7.165000
# 75%       1995.000000  8.850000e+03        16.987500
# max      38487.000000  1.186600e+06        99.000000

# %%
df.shape
# Out:
# (1534, 10)

# %%
X = df.drop(columns='price(in lakhs)')
y = df['price(in lakhs)']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    train_size=0.7,
                                                    random_state=42)

# %% [markdown]
# # Завдання 2
# Створіть Pipeline для обробки числових стовпчиків(заповнення пропусків)

# %%
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, PolynomialFeatures

num_transformer = Pipeline(
    steps=[('impute', SimpleImputer(strategy='mean')),
           ('scale', StandardScaler()),
           ('poly', PolynomialFeatures(degree=4))
    ]
)

# %% [markdown]
# # Завдання 3
# Створіть Pipeline для обробки категоріальних стовпчиків(заповнення пропусків та кодування)

# %%
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder

cat_transformer = Pipeline(
    steps=[('impute', SimpleImputer(strategy='most_frequent')),
           ('onehot', OneHotEncoder(sparse_output=False,
                                    handle_unknown='ignore'))
            # ('encoder', OrdinalEncoder(handle_unknown='use_encoded_value',
            #                            unknown_value=100))
        ]
)

# %% [markdown]
# # Завдання 4
# Об'єднайте попередні Pipeline в один ColumnTransformer

# %%
from sklearn.compose import ColumnTransformer


num_columns = X.select_dtypes(include='number').columns
cat_columns = X.select_dtypes(include='object').columns


preprocessor = ColumnTransformer(
    transformers=[
        ('num', num_transformer, num_columns),
        ('cat', cat_transformer, cat_columns)
    ]
)

preprocessor
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('impute', SimpleImputer()),
#                                                  ('scale', StandardScaler()),
#                                                  ('poly',
#                                                   PolynomialFeatures(degree=4))]),
#                                  Index(['seats', 'kms_driven', 'mileage(kmpl)', 'engine(cc)', 'max_power(bhp)',
#        'torque(Nm)'],
#       dtype='object')),
#                                 ('cat',
#                                  Pipeline(steps=[('impute',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehot',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False))]),
#                                  Index(['insurance_validity', 'fuel_type', 'manufacturing_year'], dtype='object'))])

# %% [markdown]
# # Завдання 5
# Створіть остаточну модель та натренуйте її

# %%
from sklearn.linear_model import LinearRegression

model = Pipeline(
    steps=[('prep', preprocessor),
           ('model', LinearRegression())]
)

model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer()),
#                                                                   ('scale',
#                                                                    StandardScaler()),
#                                                                   ('poly',
#                                                                    PolynomialFeatures(degree=4))]),
#                                                   Index(['seats', 'kms_driven', 'mileage(kmpl)', 'engine(cc)', 'max_power(bhp)',
#        'torque(Nm)'],
#       dtype='object')),
#                                                  ('cat',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   Index(['insurance_validity', 'fuel_type', 'manufacturing_year'], dtype='object'))])),
#                 ('model', LinearRegression())])

# %%
model['prep'].set_output(transform='pandas')
model['prep'].transform(X_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:486: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:486: UserWarning: X has feature names, but PolynomialFeatures was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:486: UserWarning: X has feature names, but OneHotEncoder was fitted without feature names
#   warnings.warn(
#       num__1  num__seats  num__kms_driven  num__mileage(kmpl)  \
# 380      1.0   -0.030638        -0.727840           -0.353577
# 288      1.0   -0.030638         0.648206           -0.361490
# 1491     1.0   -0.030638        -0.970705           -0.360952
# 766      1.0   -0.030638         1.666010           -0.358170
# 126      1.0   -0.030638        -0.084381           -0.357166
# ...      ...         ...              ...                 ...
# 1147     1.0   -0.030638        -0.401370           -0.354761
# 1312     1.0   -0.030638        -0.840623           -0.351890
# 871      1.0   -0.030638        -0.594763           -0.365976
# 1478     1.0   -0.030638        -1.379916           -0.361831
# 1143     1.0   -0.030638         0.303504           -0.368417
#
#       num__engine(cc)  num__max_power(bhp)  num__torque(Nm)  num__seats^2  \
# 380         -0.344082            -0.344082        -0.153262      0.000939
# 288         -0.293801            -0.293801        -0.055539      0.000939
# 1491        -0.293801            -0.293801        -0.055503      0.000939
# 766         -0.226760            -0.226760        -0.141005      0.000939
# 126         -0.293801            -0.293801        -0.055575      0.000939
# ...               ...                  ...              ...           ...
# 1147        -0.293801            -0.293801        -0.047508      0.000939
# 1312        -0.344336            -0.344336        -0.073335      0.000939
# 871         -0.102582            -0.102582        -0.130987      0.000939
# 1478        -0.344082            -0.344082        -0.016828      0.000939
# 1143        -0.092170            -0.092170         0.063918      0.000939
#
#       num__seats kms_driven  num__seats mileage(kmpl)  ...  \
# 380                0.022299                  0.010833  ...
# 288               -0.019860                  0.011075  ...
# 1491               0.029740                  0.011059  ...
# 766               -0.051043                  0.010974  ...
# 126                0.002585                  0.010943  ...
# ...                     ...                       ...  ...
# 1147               0.012297                  0.010869  ...
# 1312               0.025755                  0.010781  ...
# 871                0.018222                  0.011213  ...
# 1478               0.042277                  0.011086  ...
# 1143              -0.009299                  0.011287  ...
#
#       cat__manufacturing_year_2017  cat__manufacturing_year_2018  \
# 380                            1.0                           0.0
# 288                            1.0                           0.0
# 1491                           0.0                           1.0
# 766                            0.0                           0.0
# 126                            0.0                           0.0
# ...                            ...                           ...
# 1147                           0.0                           0.0
# 1312                           0.0                           0.0
# 871                            0.0                           0.0
# 1478                           0.0                           0.0
# 1143                           0.0                           0.0
#
#       cat__manufacturing_year_2019  cat__manufacturing_year_2020  \
# 380                            0.0                           0.0
# 288                            0.0                           0.0
# 1491                           0.0                           0.0
# 766                            1.0                           0.0
# 126                            1.0                           0.0
# ...                            ...                           ...
# 1147                           0.0                           0.0
# 1312                           1.0                           0.0
# 871                            0.0                           1.0
# 1478                           0.0                           0.0
# 1143                           0.0                           0.0
#
#       cat__manufacturing_year_2021  cat__manufacturing_year_2022  \
# 380                            0.0                           0.0
# 288                            0.0                           0.0
# 1491                           0.0                           0.0
# 766                            0.0                           0.0
# 126                            0.0                           0.0
# ...                            ...                           ...
# 1147                           0.0                           1.0
# 1312                           0.0                           0.0
# 871                            0.0                           0.0
# 1478                           0.0                           1.0
# 1143                           0.0                           0.0
#
#       cat__manufacturing_year_2023  cat__manufacturing_year_Air Conditioner  \
# 380                            0.0                                      0.0
# 288                            0.0                                      0.0
# 1491                           0.0                                      0.0
# 766                            0.0                                      0.0
# 126                            0.0                                      0.0
# ...                            ...                                      ...
# 1147                           0.0                                      0.0
# 1312                           0.0                                      0.0
# 871                            0.0                                      0.0
# 1478                           0.0                                      0.0
# 1143                           0.0                                      0.0
#
#       cat__manufacturing_year_Power Steering  \
# 380                                      0.0
# 288                                      0.0
# 1491                                     0.0
# 766                                      0.0
# 126                                      0.0
# ...                                      ...
# 1147                                     0.0
# 1312                                     0.0
# 871                                      0.0
# 1478                                     0.0
# 1143                                     0.0
#
#       cat__manufacturing_year_Power Windows Front
# 380                                           0.0
# 288                                           0.0
# 1491                                          0.0
# 766                                           0.0
# 126                                           0.0
# ...                                           ...
# 1147                                          0.0
# 1312                                          0.0
# 871                                           0.0
# 1478                                          0.0
# 1143                                          0.0
#
# [1073 rows x 238 columns]

# %% [markdown]
# # Завдання 6
# Виведіть основні метрики моделі

# %%
from sklearn import metrics

def get_metrics(y_true, y_pred, name="model"):
  df = pd.DataFrame()

  df.loc["MAE", name] = metrics.mean_absolute_error(y_true, y_pred)
  #df.loc["MSE", name] = metrics.mean_squared_error(y_true, y_pred)
  df.loc["RMSE", name] = metrics.mean_squared_error(y_true, y_pred) ** 0.5
  df.loc["R2", name] = metrics.r2_score(y_true, y_pred)

  return df.round(2)

# %%
all_metrics = pd.DataFrame()

y_pred = model.predict(X_train)
all_metrics['train'] = get_metrics(y_train, y_pred)

y_pred = model.predict(X_test)
all_metrics['test'] = get_metrics(y_test, y_pred)

all_metrics
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:486: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:486: UserWarning: X has feature names, but PolynomialFeatures was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:486: UserWarning: X has feature names, but OneHotEncoder was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:486: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:486: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:486: UserWarning: X has feature names, but PolynomialFeatures was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:486: UserWarning: X has feature names, but OneHotEncoder was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:486: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
#       train        test
# MAE    5.09     2602.22
# RMSE   8.51    30681.98
# R2     0.78 -3037526.73

# %% [markdown]
# # Завдання 7
# Збережіть модель

# %%
data = pd.DataFrame({'fuel_type': ['Diesel'],
                     'kms_driven': [48000],
                     'engine(cc)': [1832]})

data
# Out:
#   fuel_type  kms_driven  engine(cc)
# 0    Diesel       48000        1832

# %%
model.predict(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-162-c8644be457c1> in <cell line: 1>()
# ----> 1 model.predict(data)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/pipeline.py in predict(self, X, **params)
#     598         if not _routing_enabled():
#     599             for _, name, transform in self._iter(with_final=False):
# --> 600                 Xt = transform.transform(Xt)
#     601             return self.steps[-1][1].predict(Xt, **params)
#     602
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     314     @wraps(f)
#     315     def wrapped(self, X, *args, **kwargs):
# --> 316         data_to_wrap = f(self, X, *args, **kwargs)
#     317         if isinstance(data_to_wrap, tuple):
#     318             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.10/dist-packages/sklearn/compose/_column_transformer.py in transform(self, X, **params)
#    1063             diff = all_names - set(column_names)
#    1064             if diff:
# -> 1065                 raise ValueError(f"columns are missing: {diff}")
#    1066         else:
#    1067             # ndarray was used for fitting or transforming, thus we only
#
# ValueError: columns are missing: {'max_power(bhp)', 'seats', 'manufacturing_year', 'mileage(kmpl)', 'torque(Nm)', 'insurance_validity'}
